# %% [markdown]
# # 1_in

# %%
# %%capture
import bencher as bch
from bencher.example.meta.example_meta import BenchableObject

bench = BenchableObject().to_bench(bch.BenchRunCfg())
res=bench.plot_sweep(input_vars=['float1'],result_vars=["distance"] )
# Out:
# INFO: setting worker from bench class.__call__
# INFO: Copy run cfg from bench class
# INFO: result var: distance
# INFO: removing float1 from constants
# INFO: Taking 10 samples from float1 with values: [0.0,0.1111111111111111,0.2222222222222222,0.3333333333333333,0.4444444444444444,0.5555555555555556,0.6666666666666666,0.7777777777777777,0.8888888888888888,1.0]
# INFO: Taking 1 samples from repeat with values: [1]
# INFO: Sweeping float1:call 1/10 NOT in cache starting serial job...
# INFO: Sweeping float1:call 1/10:
# INFO: 	 float1:0.0
# INFO: 	 float2:0
# INFO: 	 float3:0
# INFO: 	 negate_output:positive
# INFO: 	 noise_distribution:uniform
# INFO: 	 noisy:False
# INFO: 	 repeat:1
# INFO: 	 sigma:1
# INFO: distance: 0.0
# INFO: Sweeping float1:call 2/10 NOT in cache starting serial job...
# INFO: Sweeping float1:call 2/10:
# INFO: 	 float1:0.1111111111111111
# INFO: 	 float2:0
# INFO: 	 float3:0
# INFO: 	 negate_output:positive
# INFO: 	 noise_distribution:uniform
# INFO: 	 noisy:False
# INFO: 	 repeat:1
# INFO: 	 sigma:1
# INFO: distance: 0.012345679012345678
# INFO: Sweeping float1:call 3/10 NOT in cache starting serial job...
# INFO: Sweeping float1:call 3/10:
# INFO: 	 float1:0.2222222222222222
# INFO: 	 float2:0
# INFO: 	 float3:0
# INFO: 	 negate_output:positive
# INFO: 	 noise_distribution:uniform
# INFO: 	 noisy:False
# INFO: 	 repeat:1
# INFO: 	 sigma:1
# INFO: distance: 0.04938271604938271
# INFO: Sweeping float1:call 4/10 NOT in cache starting serial job...
# INFO: Sweeping float1:call 4/10:
# INFO: 	 float1:0.3333333333333333
# INFO: 	 float2:0
# INFO: 	 float3:0
# INFO: 	 negate_output:positive
# INFO: 	 noise_distribution:uniform
# INFO: 	 noisy:False
# INFO: 	 repeat:1
# INFO: 	 sigma:1
# INFO: distance: 0.1111111111111111
# INFO: Sweeping float1:call 5/10 NOT in cache starting serial job...
# INFO: Sweeping float1:call 5/10:
# INFO: 	 float1:0.4444444444444444
# INFO: 	 float2:0
# INFO: 	 float3:0
# INFO: 	 negate_output:positive
# INFO: 	 noise_distribution:uniform
# INFO: 	 noisy:False
# INFO: 	 repeat:1
# INFO: 	 sigma:1
# INFO: distance: 0.19753086419753085
# INFO: Sweeping float1:call 6/10 NOT in cache starting serial job...
# INFO: Sweeping float1:call 6/10:
# INFO: 	 float1:0.5555555555555556
# INFO: 	 float2:0
# INFO: 	 float3:0
# INFO: 	 negate_output:positive
# INFO: 	 noise_distribution:uniform
# INFO: 	 noisy:False
# INFO: 	 repeat:1
# INFO: 	 sigma:1
# INFO: distance: 0.308641975308642
# INFO: Sweeping float1:call 7/10 NOT in cache starting serial job...
# INFO: Sweeping float1:call 7/10:
# INFO: 	 float1:0.6666666666666666
# INFO: 	 float2:0
# INFO: 	 float3:0
# INFO: 	 negate_output:positive
# INFO: 	 noise_distribution:uniform
# INFO: 	 noisy:False
# INFO: 	 repeat:1
# INFO: 	 sigma:1
# INFO: distance: 0.4444444444444444
# INFO: Sweeping float1:call 8/10 NOT in cache starting serial job...
# INFO: Sweeping float1:call 8/10:
# INFO: 	 float1:0.7777777777777777
# INFO: 	 float2:0
# INFO: 	 float3:0
# INFO: 	 negate_output:positive
# INFO: 	 noise_distribution:uniform
# INFO: 	 noisy:False
# INFO: 	 repeat:1
# INFO: 	 sigma:1
# INFO: distance: 0.6049382716049381
# INFO: Sweeping float1:call 9/10 NOT in cache starting serial job...
# INFO: Sweeping float1:call 9/10:
# INFO: 	 float1:0.8888888888888888
# INFO: 	 float2:0
# INFO: 	 float3:0
# INFO: 	 negate_output:positive
# INFO: 	 noise_distribution:uniform
# INFO: 	 noisy:False
# INFO: 	 repeat:1
# INFO: 	 sigma:1
# INFO: distance: 0.7901234567901234
# INFO: Sweeping float1:call 10/10 NOT in cache starting serial job...
# INFO: Sweeping float1:call 10/10:
# INFO: 	 float1:1.0
# INFO: 	 float2:0
# INFO: 	 float3:0
# INFO: 	 negate_output:positive
# INFO: 	 noise_distribution:uniform
# INFO: 	 noisy:False
# INFO: 	 repeat:1
# INFO: 	 sigma:1
# INFO: distance: 1.0
# INFO: saving results with key: 52f7460490196d89bedac41c5b6c05283a18abe7
# INFO: saving benchmark: BenchableObject
# INFO: job calls: 10
# INFO: cache calls: 0
# INFO: worker calls: 10
# INFO:

# %%
from bokeh.io import output_notebook
output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c6a9443a-2f87-4fd3-b72b-122bad882a9e">Loading BokehJS ...</span>
#     </div>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'f721a39a-3e03-4702-90e7-8c707152f51b': {'version…
